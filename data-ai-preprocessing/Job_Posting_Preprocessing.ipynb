# %% [markdown]
# ### Overview

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/wuzzuf_jobs_final.csv', on_bad_lines='skip', engine='python')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12355 entries, 0 to 12354
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              12355 non-null  object
#  1   Company            11916 non-null  object
#  2   Date               11733 non-null  object
#  3   Job Type           11651 non-null  object
#  4   Work Setting       7495 non-null   object
#  5   Location           12335 non-null  object
#  6   Experience Needed  12344 non-null  object
#  7   Career Level       12344 non-null  object
#  8   Education Level    12344 non-null  object
#  9   Salary             12344 non-null  object
#  10  Job Categories     12344 non-null  object
#  11  Skills             12019 non-null  object
#  12  Job Description    12338 non-null  object
#  13  Job Requirements   8402 non-null   object
#  14  Link               12355 non-null  object
# dtypes: object(15)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Title                   0
# Company               439
# Date                  622
# Job Type              704
# Work Setting         4860
# Location               20
# Experience Needed      11
# Career Level           11
# Education Level        11
# Salary                 11
# Job Categories         11
# Skills                336
# Job Description        17
# Job Requirements     3953
# Link                    0
# dtype: int64

# %%
print(f"\nTotal rows: {len(df)}")
# Out:
# Total rows: 12355

# %% [markdown]
# ### Title

# %%
print(f"Null values: {df['Title'].isnull().sum()}")
# Out:
# Null values: 0

# %%
empty_strings = (df['Title'].astype(str).str.strip() == '').sum()
print(f"Empty strings: {empty_strings}")
# Out:
# Empty strings: 0

# %%
not_specified_mask = df['Title'].astype(str).str.lower().str.contains(
    'not specified|not specific|n/a|na |none|confidential',
    na=False
)
not_specified_count = not_specified_mask.sum()
print(f"Contains nulls:  {not_specified_count}")
# Out:
# Contains nulls:  1

# %%
df[not_specified_mask]
# Out:
#                                 Title                 Company  \
# 11632  N/A - Cybersecurity - Products  Tata Communications\n-
#
#                      Date   Job Type Work Setting              Location  \
# 11632  posted 10 days ago  Full Time          NaN  United Arab Emirates
#
#       Experience Needed                             Career Level  \
# 11632     Not Specified  Entry Level (Junior Level / Fresh Grad)
#
#       Education Level        Salary           Job Categories  \
# 11632   Not Specified  Confidential  IT/Software Development
#
#                                                   Skills  \
# 11632  information technology (it), computer science,...
#
#                                          Job Description Job Requirements  \
# 11632  - About The CompanyTata Communications Redefin...              NaN
#
#                                                     Link
# 11632  https://wuzzuf.net/jobs/p/g/n4lq6plnys2a--cybe...

# %%
short_titles = df['Title'].astype(str).str.len() < 4
short_count = short_titles.sum()
print(f"Titles with less than 3 characters: {short_count}")
# Out:
# Titles with less than 3 characters: 4

# %%
print(df[short_titles]['Title'])
# Out:
# 1687     CFO
# 2975     CFO
# 4783     CFO
# 10500    CFO
# Name: Title, dtype: object

# %%
print(f"Unique titles: {df['Title'].nunique()}")
# Out:
# Unique titles: 8264

# %%
def has_encoding_issues(text):
    if pd.isna(text):
        return False
    text = str(text)
    issues = ['�', 'â€', 'Ã', '\x00']
    return any(char in text for char in issues)

# %%
encoding_problems = df['Title'].apply(has_encoding_issues).sum()
print(f"Titles with potential encoding issues: {encoding_problems}")
# Out:
# Titles with potential encoding issues: 0

# %% [markdown]
# ### Company

# %%
df['Company'].isnull().sum()
# Out:
# np.int64(439)

# %%
(df['Company'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
problematic_mask = df['Company'].astype(str).str.lower().str.contains(
    'not specified|not specific|n/a|confidential|undisclosed|anonymous|hidden',
    na=False,
    regex=True
)
problematic_count = problematic_mask.sum()
print(f"Contains problematic phrases: {problematic_count}")

if problematic_count > 0:
    print("\nExamples of problematic companies:")
    print(df[problematic_mask]['Company'].value_counts().head(10))
# Out:
# Contains problematic phrases: 877
#
# Examples of problematic companies:
# Company
# Confidential Company\n-       875
# Confidential Government\n-      2
# Name: count, dtype: int64

# %%
df['Company'] = df['Company'].str.replace('Confidential Company\n-', 'Confidential', regex=False)
df['Company'] = df['Company'].str.replace('Confidential Government\n-', 'Confidential - Government', regex=False)

# %%
df['Company'] = df['Company'].fillna('Confidential')

# %%
print(f"Unique companies: {df['Company'].nunique()}")
# Out:
# Unique companies: 3362

# %%
df['Company'].apply(has_encoding_issues).sum()
# Out:
# np.int64(0)

# %%
import re

# %%
def contains_arabic(text):
    arabic_pattern = re.compile(r'[\u0600-\u06FF]')
    return bool(arabic_pattern.search(str(text)))

# %%
arabic_mask = df['Company'].apply(contains_arabic)
arabic_count = arabic_mask.sum()
print(arabic_count)
# Out:
# 103

# %%
df['Company'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns='Date', inplace=True)

# %% [markdown]
# ### Job Type

# %%
df['Job Type'].isnull().sum()
# Out:
# np.int64(704)

# %%
(df['Job Type'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
print(df['Job Type'].value_counts())
# Out:
# Job Type
# Full Time              11156
# Freelance / Project      239
# Internship               120
# Part Time                105
# دوام كامل                 21
# Shift Based                9
# تدريب عملي                 1
# Name: count, dtype: int64

# %%
df['Job Type'] = df['Job Type'].replace({'دوام كامل': 'Full Time', 'تدريب عملي': 'Internship'
})

# %%
career_job_mapping = df.groupby('Career Level')['Job Type'].agg(lambda x: x.mode()[0] if not x.mode().empty else 'Full Time').to_dict()

# %%
def impute_job_type(row):

    if pd.notna(row['Job Type']):
        return row['Job Type']

    title = str(row['Title']).lower()
    career_level = row['Career Level']

    if 'intern' in title:
        return 'Internship'

    if 'freelance' in title or 'freelancer' in title:
        return 'Freelance / Project'

    if 'part time' in title or 'part-time' in title:
        return 'Part Time'

    if 'contract' in title or 'temporary' in title or 'temp ' in title:
        return 'Freelance / Project'

    if pd.notna(career_level) and career_level in career_job_mapping:
        return career_job_mapping[career_level]

    return 'Full Time'

# %%
df['Job Type'] = df.apply(impute_job_type, axis=1)

# %%
df['Job Type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Job Type'].astype(str).str.lower().str.contains(
    'not specified|not specific|n/a|none|unknown',
    na=False
).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Work Setting

# %%
df['Work Setting'].isnull().sum()
# Out:
# np.int64(4860)

# %%
(df['Work Setting'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
print(df['Work Setting'].value_counts())
# Out:
# Work Setting
# On-site              6506
# Hybrid                516
# Remote                457
# عمل من مقر الشركة      14
# عمل عن بُعد             1
# عمل هجين                1
# Name: count, dtype: int64

# %%
df['Work Setting'] = df['Work Setting'].replace({
    'عمل من مقر الشركة': 'On-site',
    'عمل عن بُعد': 'Remote',
    'عمل هجين': 'Hybrid'
})

# %%
df['Work Setting'] = df['Work Setting'].fillna('Not Specified')

# %% [markdown]
# ### Location

# %%
df['Location'].isnull().sum()
# Out:
# np.int64(20)

# %%
(df['Location'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
df['Location'].nunique()
# Out:
# 69

# %%
df['Location'].astype(str).str.lower().str.contains(
    'not specified|not specific|n/a|none|unknown|unspecified',
    na=False
).sum()
# Out:
# np.int64(0)

# %%
print(df[df['Location'].apply(contains_arabic)]['Location'].value_counts())
# Out:
# Location
# القاهرة                     7
# مصر                         6
# الإمارات العربية المتحدة    4
# الجيزة                      2
# المملكة العربية السعودية    2
# البحر الأحمر                1
# الشرقية                     1
# Name: count, dtype: int64

# %%
df['Location'] = df['Location'].replace({
    'القاهرة': 'Cairo',
    'مصر': 'Egypt',
    'الإمارات العربية المتحدة': 'United Arab Emirates',
    'الجيزة': 'Giza',
    'المملكة العربية السعودية': 'Saudi Arabia',
    'البحر الأحمر': 'Red Sea',
    'الشرقية': 'Sharqia'
})

# %%
df['Location'] = df['Location'].fillna('Not Specified')

# %% [markdown]
# ### Work Experience

# %%
df['Experience Needed'].isnull().sum()
# Out:
# np.int64(11)

# %%
(df['Experience Needed'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
df['Experience Needed'].value_counts()
# Out:
# Experience Needed
# Not Specified     4098
# 3 To 5 Years       833
# 1 To 3 Years       752
# 2 To 5 Years       550
# 2 To 4 Years       385
#                   ...
# 0 To 11 Years        1
# 10 To 14 Years       1
# 15 To 17 Years       1
# 5 To 18 Years        1
# 8 Years              1
# Name: count, Length: 147, dtype: int64

# %%
df['Experience Needed'].apply(contains_arabic).sum()
# Out:
# np.int64(0)

# %%
df['Experience Needed'] = df['Experience Needed'].fillna('Not Specified')

# %% [markdown]
# ### Career Level

# %%
df['Career Level'].isnull().sum()
# Out:
# np.int64(11)

# %%
(df['Career Level'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
print(df['Career Level'].value_counts())
# Out:
# Career Level
# Experienced (Non-Mager)                      6682
# Entry Level (Junior Level / Fresh Grad)      3616
# Mager                                        1245
# Education Level:                              325
# Senior Magement (CEO, GM, Director, Head)     248
# Not Specified                                 153
# Student (Undergrad / Postgrad)                 54
# ذو خبرة (غير إداري)                            12
# مستوى مبتدئ (مبتدئ / خريج جديد)                 5
# مدير                                            3
# طالب (طالب جامعي / دراسات عُليا)                1
# Name: count, dtype: int64

# %%
df = df[df['Career Level'] != 'Education Level:']

# %%
df['Career Level'] = df['Career Level'].replace('Mager', 'Manager')

# %%
df['Career Level'] = df['Career Level'].replace({
    'ذو خبرة (غير إداري)': 'Experienced (Non-Manager)',
    'مستوى مبتدئ (مبتدئ / خريج جديد)': 'Entry Level (Junior Level / Fresh Grad)',
    'مدير': 'Manager',
    'طالب (طالب جامعي / دراسات عُليا)': 'Student (Undergrad / Postgrad)'
})

# %%
df['Career Level'] = df['Career Level'].fillna('Not Specified')

# %%
df['Career Level'] = df['Career Level'].replace('Experienced (Non-Mager)', 'Experienced (Non-Manager)')

# %%
print(df['Career Level'].value_counts())
# Out:
# Career Level
# Experienced (Non-Manager)                    6694
# Entry Level (Junior Level / Fresh Grad)      3621
# Manager                                      1248
# Senior Magement (CEO, GM, Director, Head)     248
# Not Specified                                 164
# Student (Undergrad / Postgrad)                 55
# Name: count, dtype: int64

# %% [markdown]
# ### Education Level

# %%
df['Education Level'].isnull().sum()
# Out:
# np.int64(11)

# %%
(df['Education Level'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
print(df['Education Level'].value_counts())
# Out:
# Education Level
# Not Specified                  6283
# Bachelor's Degree              5651
# High School (Or Equivalent)      28
# Master's Degree                  19
# درجة البكالوريوس                 12
# غير محدد                          9
# Diploma                           9
# MBA                               6
# Doctorate                         2
# Name: count, dtype: int64

# %%
df['Education Level']=df['Education Level'].replace({
    "غير محدد": "Not Specified",
    "درجة البكالوريوس": "Bachelor's Degree",
})

# %%
df['Education Level']=df['Education Level'].fillna('Not Specified')

# %%
print(df['Education Level'].value_counts())
# Out:
# Education Level
# Not Specified                  6303
# Bachelor's Degree              5663
# High School (Or Equivalent)      28
# Master's Degree                  19
# Diploma                           9
# MBA                               6
# Doctorate                         2
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Title', 'Company', 'Job Type', 'Work Setting', 'Location',
#        'Experience Needed', 'Career Level', 'Education Level', 'Salary',
#        'Job Categories', 'Skills', 'Job Description', 'Job Requirements',
#        'Link'],
#       dtype='object')

# %% [markdown]
# ### Salary

# %%
df['Salary'].isnull().sum()
# Out:
# np.int64(11)

# %%
df['Salary'].value_counts().head(100)
# Out:
# Salary
# Confidential                                                               9706
# Paid                                                                         70
# Confidential, Commission                                                     42
# Confidential, Bonus                                                          37
# 8000 To 12000 EGP Per Month                                                  36
#                                                                            ...
# Confidential, Social Insurance Medical Insurance Transportation In Work       3
# 400 To 500 USD Per Month                                                      3
# Confidential, Device & Headset Will Be Provided.                              3
# 15000 To 20000 SAR Per Month                                                  3
# Confidential, 00                                                              3
# Name: count, Length: 100, dtype: int64

# %%
df.drop(columns='Salary', inplace=True)

# %% [markdown]
# ### Job Categories

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12030 entries, 0 to 12354
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              12030 non-null  object
#  1   Company            12030 non-null  object
#  2   Job Type           12030 non-null  object
#  3   Work Setting       12030 non-null  object
#  4   Location           12030 non-null  object
#  5   Experience Needed  12030 non-null  object
#  6   Career Level       12030 non-null  object
#  7   Education Level    12030 non-null  object
#  8   Job Categories     12019 non-null  object
#  9   Skills             12019 non-null  object
#  10  Job Description    12030 non-null  object
#  11  Job Requirements   8198 non-null   object
#  12  Link               12030 non-null  object
# dtypes: object(13)
# memory usage: 1.3+ MB

# %%
df['Job Categories'].isnull().sum()
# Out:
# np.int64(11)

# %%
print(df['Job Categories'].nunique())
# Out:
# 49

# %%
(df['Job Categories'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
df['Job Categories'].astype(str).str.lower().str.contains(
    'not specified|not specific|n/a|none|unknown',
    na=False
).sum()
# Out:
# np.int64(604)

# %%
df['Job Categories'].apply(contains_arabic).sum()
# Out:
# np.int64(21)

# %%
print(df[df['Job Categories'].apply(contains_arabic)]['Job Categories'].value_counts().head(100))
# Out:
# Job Categories
# الهندسة - البناء/المدنية/المعمارية     6
# التعليم/التدريس                        2
# تكنولوجيا المعلومات/تطوير البرمجيات    2
# الإدارة                                2
# المبيعات/التجزئة                       2
# التسويق/العلاقات العامة/الإعلان        2
# العمليات/الإدارة                       1
# خدمة العملاء/الدعم                     1
# المحاسبة/المالية                       1
# الطب/الرعاية الصحية                    1
# الكتابة/التحرير                        1
# Name: count, dtype: int64

# %%
arabic_translations = {
    'الهندسة - البناء/المدنية/المعمارية': 'Engineering - Construction/Civil/Architecture',
    'التعليم/التدريس': 'Education/Teaching',
    'تكنولوجيا المعلومات/تطوير البرمجيات': 'IT/Software Development',
    'الإدارة': 'Administration',
    'المبيعات/التجزئة': 'Sales/Retail',
    'التسويق/العلاقات العامة/الإعلان': 'Marketing/PR/Advertising',
    'العمليات/الإدارة': 'Operations/Management',
    'خدمة العملاء/الدعم': 'Customer Service/Support',
    'المحاسبة/المالية': 'Accounting/Finance',
    'الطب/الرعاية الصحية': 'Medical/Healthcare',
    'الكتابة/التحرير': 'Writing/Editorial'
}

df['Job Categories'] = df['Job Categories'].replace(arabic_translations)

# %%
df=df.dropna(subset=['Job Categories'])

# %%
corrections = {
    "Accounting/Fince": "Accounting / Finance",
    "Accounting/Finance": "Accounting / Finance",
    "Installation/Maintence/Repair": "Installation / Maintenance / Repair",
    "Operations/Magement": "Operations / Management",
    "Operations/Management": "Operations / Management",
    "Project/Program Magement": "Project / Program Management",
    "Alyst/Research": "Analyst / Research",
    "Media/Jourlism/Publishing": "Media / Journalism / Publishing",
    "Engineering - Oil & Gas/Energy": "Engineering - Oil & Gas / Energy",
}

# %%
df["Job Categories"] = (
    df["Job Categories"]
    .replace(corrections)
    .str.replace(r"\s*/\s*", " / ", regex=True)
    .str.replace(r"\s*-\s*", " - ", regex=True)
    .str.strip()
    .str.title()
)

# %% [markdown]
# ### Skills

# %%
df['Skills'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df['Skills'].astype(str).str.strip() == '').sum()
# Out:
# np.int64(0)

# %%
df['Skills'].nunique()
# Out:
# 10069

# %%
df['Skills'].value_counts().head()
# Out:
# Skills
# Business Development, Sales, Sales Skills, Sales Target, Marketing, Customer Service, Customer Support, Customer Care, Market Research, Magement                        33
# Sales, Sales Skills, Sales Target, Customer Service, Customer Support, Customer Care, Microsoft Office, Marketing, Business Development, Outdoor Sales                  32
# Sales, Sales Skills, Customer Service, Sales Target, Customer Support, Customer Care, Account Magement, Marketing, Business Development, Information Technology (IT)    29
# Microsoft Office, Sales, Administration, Magement, Sales Skills, Office Magement, Customer Service, Accounting, Fince, Marketing                                        27
# Sales, Sales Skills, Sales Target, Customer Service, Magement, Customer Support, Customer Care, Marketing, Business Development, Microsoft Office                       24
# Name: count, dtype: int64

# %%
df['Skills'].apply(contains_arabic).sum()
# Out:
# np.int64(3)

# %%
df[df['Skills'].apply(contains_arabic)]['Skills'].value_counts().head(15)
# Out:
# Skills
# التفاوض, التواصل الفعال, إعداد التقارير, تحليل البيانات, إدارة الموردين, استخدام برامج ERP, حل المشكلات, العمل الجماعي    1
# مدخل بيانات, محاسبة                                                                                                       1
# محاسب, السعودية, هيئة الزكاة و الضريبة و الجمارك                                                                          1
# Name: count, dtype: int64

# %%
df['Skills'] = df['Skills'].replace({
    "التفاوض, التواصل الفعال, إعداد التقارير, تحليل البيانات, إدارة الموردين, استخدام برامج ERP, حل المشكلات, العمل الجماعي":
        "Negotiation, Effective communication, Report preparation, Data analysis, Supplier management, Using ERP software, Problem solving, Teamwork",

    "مدخل بيانات, محاسبة":
        "Data entry, Accounting",

    "محاسب, السعودية, هيئة الزكاة و الضريبة و الجمارك":
        "Accountant, Saudi Arabia, Zakat, Tax and Customs Authority"
})

# %%
df['Skills'] = df['Skills'].replace({
    'Magement': 'Management',
    'Fince': 'Finance',
    'Fincial': 'Financial',
    'Alysis': 'Analysis',
    'Alytical': 'Analytical',
    'Organizatiol': 'Organizational',
    'Persol': 'Personal',
    'Coordition': 'Coordination',
    'Maintence': 'Maintenance',
    'Telesales': 'Tele Sales'
})

# %%
skill_map = {
        'ms office': 'Microsoft Office',
        'ms excel': 'Microsoft Excel',
        'ms word': 'Microsoft Word',
        'powerpoint': 'Microsoft PowerPoint',
        'excel': 'Microsoft Excel',
        'word': 'Microsoft Word',
        'admin': 'Administration',
        'admin work': 'Administration',
        'admin assistant': 'Administrative Assistant',
        'hr': 'Human Resources',
        'it': 'Information Technology',
        'qa': 'Quality Assurance',
        'qc': 'Quality Control',
        'f&b': 'Food & Beverage',
        'crm': 'CRM Software',
        'erp': 'ERP Systems',
        'pmp': 'Project Management Professional',
        'seo': 'Search Engine Optimization',
        'css': 'CSS',
        'html': 'HTML',
        'javascript': 'JavaScript',
        'jquery': 'jQuery',
    }
df['Skills'] = df['Skills'].replace(skill_map)

# %%
print(df['Skills'].sample(10))
# Out:
# 170     Civil Engineering, Tendering, Estimation, Saud...
# 7549    ELA teacher, Social studies teacher, American ...
# 4004    Video Editing, Adobe After Effects, Adobe Phot...
# 2056    Talent Acquisition, Candidate Sourcing, Recrui...
# 6699    Accounting, Fince, Microsoft Office, Sales Ski...
# 9901              Sales Target, Indoor Sales, Sales Field
# 7325    sales, retail, sales skills, customer service,...
# 4275             Sales, Customer Service, Computer Skills
# 912     Engineering, Civil Engineering, Swimming Pools...
# 5972    English Teaching, English Education, Kids Teac...
# Name: Skills, dtype: object

# %%
def clean_skills(skills_str):

    skills = [s.strip() for s in skills_str.split(',')]
    skills = [s for s in skills if s]

    cleaned_skills = []
    for skill in skills:
        skill = skill.title()
        skill_lower = skill.lower()
        skill = skill_map.get(skill_lower, skill)
        cleaned_skills.append(skill)

    seen = set()
    unique_skills = []
    for skill in cleaned_skills:
        if skill.lower() not in seen:
            seen.add(skill.title())
            unique_skills.append(skill)

    skills_str = ', '.join(unique_skills)
    return skills_str

# %%
df['Skills'] = df['Skills'].apply(clean_skills)

# %%
print(df['Skills'].head())
# Out:
# 0    Administration, Office Magement, Microsoft Off...
# 1    Autocad, Mechanical Design, Shop Drawings Prep...
# 2    Administration, Office Magement, Microsoft Off...
# 3    Lean Manufacturing, Problem-Solving, Productio...
# 4    Graphic Design, Adobe Photoshop, Adobe Illustr...
# Name: Skills, dtype: object

# %% [markdown]
# ### Job Description and Requirements

# %%
import re

# %%
def clean_text_basic(text):
    if pd.isna(text) or not text:
        return ""

    text = str(text).strip()

    text = re.sub(r'[ \t]{2,}', ' ', text)

    text = re.sub(r'\n{3,}', '\n\n', text)

    lines = [line.strip() for line in text.split('\n')]
    text = '\n'.join(lines)

    return text.strip()

# %%
def extract_requirements_from_description(description):
    if pd.isna(description) or not description:
        return "", ""

    desc = str(description)

    req_patterns = [
        r'(?:^|\n)\s*(?:-\s*)?(?:qualifications?\s*(?:&|and)?\s*requirements?|requirements?\s*(?:&|and)?\s*qualifications?)\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?requirements?\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?qualifications?\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?job\s+requirements?\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?minimum\s+(?:requirements?|qualifications?)\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?required\s+(?:skills?|qualifications?|experience)\s*:?\s*(?:\n|$)',

        r'(?:^|\n)\s*(?:-\s*)?what\s+we(?:\'re| are)\s+looking\s+for\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?we(?:\'re| are)\s+looking\s+for\s+(?:someone|a\s+(?:candidate|professional|person))\s+(?:with|who)\s*:?\s*',
        r'(?:^|\n)\s*(?:-\s*)?looking\s+for\s+(?:someone|a\s+(?:candidate|professional|person))\s+(?:with|who)\s*:?\s*',
        r'(?:^|\n)\s*(?:-\s*)?we\s+(?:are\s+)?looking\s+for\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?we\s+(?:are\s+)?seeking\s+(?:someone|a\s+(?:candidate|professional|person))\s+(?:with|who)\s*:?\s*',
        r'(?:^|\n)\s*(?:-\s*)?seeking\s+(?:someone|a\s+(?:candidate|professional|person))\s+(?:with|who)\s*:?\s*',

        r'(?:^|\n)\s*(?:-\s*)?(?:ideal|successful|perfect)\s+candidate\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?(?:the\s+)?(?:ideal|successful|perfect)\s+candidate\s+(?:will|should|must)\s+have\s*:?\s*',
        r'(?:^|\n)\s*(?:-\s*)?you\s+should\s+have\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?you\s+(?:will\s+)?need\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?candidate\s+(?:should|must|will)\s*:?\s*(?:\n|$)',

        r'(?:^|\n)\s*(?:-\s*)?skills?\s+(?:&|and)\s+(?:experience|qualifications?)\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?experience\s+(?:&|and)\s+(?:skills?|qualifications?)\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?required\s+skills?\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?key\s+skills?\s*:?\s*(?:\n|$)',

        r'(?:^|\n)\s*(?:-\s*)?education(?:al)?\s+(?:&|and)?\s*experience\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?must\s+have\s*:?\s*(?:\n|$)',
        r'(?:^|\n)\s*(?:-\s*)?(?:essential|preferred)\s+(?:skills?|qualifications?|experience)\s*:?\s*(?:\n|$)',

        r'(?:^|\n)\s*(?:-\s*)?to\s+be\s+successful\s*,?\s*you\s+(?:will|should|must)\s*:?\s*',
        r'(?:^|\n)\s*(?:-\s*)?to\s+succeed\s+in\s+this\s+role\s*,?\s*you\s+(?:will|should|must)\s*:?\s*',
    ]

    best_match = None
    best_position = len(desc)

    for pattern in req_patterns:
        match = re.search(pattern, desc, re.IGNORECASE | re.MULTILINE)
        if match and match.start() < best_position:
            best_match = match
            best_position = match.start()

    if best_match:
        split_point = best_match.start()

        description_part = desc[:split_point].strip()

        requirements_part = desc[split_point:].strip()

        requirements_part = requirements_part[best_match.end() - best_match.start():].strip()

        if len(requirements_part) > 50:
            return description_part, requirements_part

    return desc, ""

# %%
def clean_job_description(description):
    if pd.isna(description) or not description:
        return ""

    if contains_arabic(description):
        description = re.sub(r'[\u0600-\u06FF]+', '', str(description))

    cleaned = clean_text_basic(description)

    cleaned = cleaned.replace('Magement', 'Management')
    cleaned = cleaned.replace('Fince', 'Finance')
    cleaned = cleaned.replace('Fincial', 'Financial')
    cleaned = cleaned.replace('Alysis', 'Analysis')
    cleaned = cleaned.replace('Alytical', 'Analytical')
    cleaned = cleaned.replace('Organizatiol', 'Organizational')
    cleaned = cleaned.replace('Persol', 'Personal')
    cleaned = cleaned.replace('Coordition', 'Coordination')
    cleaned = cleaned.replace('Maintence', 'Maintenance')

    return cleaned

# %%
def clean_job_requirements(requirements):
    if pd.isna(requirements) or not requirements:
        return ""

    cleaned = str(requirements)

    if contains_arabic(cleaned):
        cleaned = re.sub(r'[\u0600-\u06FF]+', '', cleaned)

    cleaned = clean_text_basic(cleaned)

    corrections = {
        'Magement': 'Management',
        'Fince': 'Finance',
        'Fincial': 'Financial',
        'Alysis': 'Analysis',
        'Alytical': 'Analytical'
    }

    for wrong, right in corrections.items():
        cleaned = cleaned.replace(wrong, right)

    return cleaned

# %%
def process_descriptions_and_requirements(df):

    df['Desc_Clean'] = ""
    df['Req_Clean'] = ""
    df['Req_Extracted'] = False
    for idx in df.index:
        description = df.loc[idx, 'Job Description']
        requirements = df.loc[idx, 'Job Requirements']

        if pd.isna(requirements) or str(requirements).strip() == '':
            desc_clean, req_extracted = extract_requirements_from_description(description)

            if req_extracted:
                df.loc[idx, 'Desc_Clean'] = clean_job_description(desc_clean)
                df.loc[idx, 'Req_Clean'] = clean_job_requirements(req_extracted)
                df.loc[idx, 'Req_Extracted'] = True
            else:
                df.loc[idx, 'Desc_Clean'] = clean_job_description(description)
                df.loc[idx, 'Req_Clean'] = "Please refer to the job description for requirements."
                df.loc[idx, 'Req_Extracted'] = False
        else:
            df.loc[idx, 'Desc_Clean'] = clean_job_description(description)
            df.loc[idx, 'Req_Clean'] = clean_job_requirements(requirements)
            df.loc[idx, 'Req_Extracted'] = False

    extracted_count = df['Req_Extracted'].sum()
    still_null = (df['Req_Clean'] == "Please refer to the job description for requirements.").sum()

    df['Job Description'] = df['Desc_Clean']
    df['Job Requirements'] = df['Req_Clean']

    df.drop(['Desc_Clean', 'Req_Clean'], axis=1, inplace=True)

    return df

# %%
df = process_descriptions_and_requirements(df)

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Grammar Fixes

# %%
import pandas as pd
import re
from collections import Counter


def extract_all_words(df, columns=None):
    """
    Extract all unique words from specified columns
    """
    if columns is None:
        columns = ['Title', 'Job Description', 'Job Requirements', 'Skills']

    columns = [col for col in columns if col in df.columns]

    print(f"Extracting words from: {columns}\n")

    all_words = []

    for col in columns:
        print(f"Processing {col}...", end=' ')
        texts = df[col].dropna().astype(str)

        for text in texts:
            words = re.findall(r'\b[a-zA-Z]+\b', text)
            all_words.extend(words)

        print(f"✓ ({len(texts)} rows)")

    return all_words


def analyze_words(words, min_frequency=5):
    """
    Analyze words and find suspicious patterns
    """
    print(f"\nAnalyzing {len(words)} total words...")

    word_counts = Counter(words)
    print(f"Found {len(word_counts)} unique words\n")

    frequent_words = {word: count for word, count in word_counts.items()
                     if count >= min_frequency}

    print(f"{'='*80}")
    print(f"WORDS APPEARING {min_frequency}+ TIMES: {len(frequent_words)}")
    print(f"{'='*80}\n")

    return word_counts, frequent_words



def find_suspicious_patterns(word_counts, min_frequency=5):
    """
    Find words with suspicious patterns that are likely typos
    """
    suspicious = []

    patterns = {
        'double letters': r'(.)\1{2,}',
        'iol ending': r'\w+iol$',
        'ence ending': r'\w+ence$',
        'ition ending': r'\w+ition$',
        'ger ending': r'\w+ger$',
        'nce/nance': r'\w+nce$',
        'ment/gement': r'\w+gement$',
        'lysis': r'\w*[Aa]lysis$',
        'lytical': r'\w*[Aa]lytical$',
    }

    for word, count in word_counts.items():
        if count < min_frequency:
            continue

        if len(word) < 4:
            continue

        for pattern_name, pattern in patterns.items():
            if re.search(pattern, word, re.IGNORECASE):
                suspicious.append({
                    'word': word,
                    'count': count,
                    'pattern': pattern_name
                })
                break

    return suspicious



def find_similar_word_pairs(word_counts, min_frequency=5):
    """
    Find pairs of similar words that might be typo variations
    """
    pairs = []
    words = [w for w, c in word_counts.items() if c >= min_frequency]

    print("Finding similar word pairs...")

    for i, word1 in enumerate(words):
        for word2 in words[i+1:]:
            if len(word1) < 4 or len(word2) < 4:
                continue

            if abs(len(word1) - len(word2)) > 2:
                continue

            if (word1.lower() in word2.lower() or
                word2.lower() in word1.lower() or
                levenshtein_distance(word1.lower(), word2.lower()) <= 2):

                count1 = word_counts[word1]
                count2 = word_counts[word2]

                if max(count1, count2) / min(count1, count2) > 3:
                    pairs.append({
                        'word1': word1,
                        'count1': count1,
                        'word2': word2,
                        'count2': count2,
                        'distance': levenshtein_distance(word1.lower(), word2.lower())
                    })

    return pairs


def levenshtein_distance(s1, s2):
    """Calculate edit distance between two strings"""
    if len(s1) < len(s2):
        return levenshtein_distance(s2, s1)

    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]



def display_top_words(word_counts, n=100):
    """Display most frequent words"""
    print(f"\n{'='*80}")
    print(f"TOP {n} MOST FREQUENT WORDS")
    print(f"{'='*80}\n")

    sorted_words = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

    print(f"{'Word':<30} {'Count':<10}")
    print("-" * 80)

    for word, count in sorted_words[:n]:
        print(f"{word:<30} {count:<10}")


def display_suspicious_words(suspicious):
    """Display words with suspicious patterns"""
    print(f"\n{'='*80}")
    print(f"SUSPICIOUS WORDS (Likely Typos)")
    print(f"{'='*80}\n")

    if not suspicious:
        print("✓ No suspicious patterns found!")
        return

    suspicious.sort(key=lambda x: x['count'], reverse=True)

    print(f"{'Word':<30} {'Count':<10} {'Pattern'}")
    print("-" * 80)

    for item in suspicious:
        print(f"{item['word']:<30} {item['count']:<10} {item['pattern']}")


def display_similar_pairs(pairs):
    """Display similar word pairs"""
    print(f"\n{'='*80}")
    print(f"SIMILAR WORD PAIRS (Potential Typo Variations)")
    print(f"{'='*80}\n")

    if not pairs:
        print("✓ No suspicious pairs found!")
        return

    pairs.sort(key=lambda x: max(x['count1'], x['count2']), reverse=True)

    print(f"{'Word 1':<25} {'Count':<8} {'Word 2':<25} {'Count':<8} {'Distance'}")
    print("-" * 80)

    for pair in pairs[:50]:
        print(f"{pair['word1']:<25} {pair['count1']:<8} "
              f"{pair['word2']:<25} {pair['count2']:<8} {pair['distance']}")


def save_to_csv(word_counts, suspicious, pairs):
    """Save results to CSV files for manual review"""

    df_words = pd.DataFrame(list(word_counts.items()), columns=['word', 'count'])
    df_words = df_words.sort_values('count', ascending=False)
    df_words.to_csv('all_words_frequency.csv', index=False)
    print(f"\n✓ Saved all words to 'all_words_frequency.csv'")

    # Suspicious words
    if suspicious:
        df_suspicious = pd.DataFrame(suspicious)
        df_suspicious.to_csv('suspicious_words.csv', index=False)
        print(f"✓ Saved suspicious words to 'suspicious_words.csv'")

    # Similar pairs
    if pairs:
        df_pairs = pd.DataFrame(pairs)
        df_pairs.to_csv('similar_word_pairs.csv', index=False)
        print(f"✓ Saved similar pairs to 'similar_word_pairs.csv'")



def review_suspicious_words(suspicious):
    """
    Interactively review suspicious words
    """
    corrections = {}

    print(f"\n{'='*80}")
    print("REVIEW SUSPICIOUS WORDS")
    print(f"{'='*80}")
    print("\nFor each word:")
    print("  y = It's a typo (then type correct spelling)")
    print("  n = Not a typo (skip)")
    print("  q = Quit review\n")

    for i, item in enumerate(suspicious, 1):
        word = item['word']
        count = item['count']
        pattern = item['pattern']

        print(f"\n[{i}/{len(suspicious)}] '{word}' - {pattern} (appears {count} times)")

        choice = input("Is this a typo? (y/n/q): ").lower().strip()

        if choice == 'y':
            correct = input(f"  Correct spelling of '{word}': ").strip()
            if correct:
                corrections[word] = correct
                print(f"  ✓ Added: {word} → {correct}")
        elif choice == 'q':
            break
        elif choice == 'n':
            print("  ⊘ Skipped")

    return corrections


def review_word_pairs(pairs):
    """
    Review similar word pairs
    """
    corrections = {}

    print(f"\n{'='*80}")
    print("REVIEW SIMILAR WORD PAIRS")
    print(f"{'='*80}")
    print("\nFor each pair, which is the typo?")
    print("  1 = First word is typo")
    print("  2 = Second word is typo")
    print("  n = Neither is typo")
    print("  q = Quit\n")

    for i, pair in enumerate(pairs[:30], 1):
        word1 = pair['word1']
        count1 = pair['count1']
        word2 = pair['word2']
        count2 = pair['count2']

        print(f"\n[{i}] '{word1}' ({count1}) vs '{word2}' ({count2})")

        choice = input("Which is typo? (1/2/n/q): ").strip()

        if choice == '1':
            corrections[word1] = word2
            print(f"  ✓ Added: {word1} → {word2}")
        elif choice == '2':
            corrections[word2] = word1
            print(f"  ✓ Added: {word2} → {word1}")
        elif choice == 'q':
            break

    return corrections



def generate_typo_dict_code(corrections):
    """
    Generate Python code for the typo dictionary
    """
    if not corrections:
        print("\n⚠️  No corrections to generate")
        return

    print(f"\n{'='*80}")
    print("GENERATED TYPO DICTIONARY CODE")
    print(f"{'='*80}\n")

    print("KNOWN_TYPOS = {")
    for typo, correction in sorted(corrections.items()):
        print(f"    '{typo}': '{correction}',")
    print("}")

    with open('typo_dictionary.txt', 'w') as f:
        f.write("KNOWN_TYPOS = {\n")
        for typo, correction in sorted(corrections.items()):
            f.write(f"    '{typo}': '{correction}',\n")
        f.write("}\n")

    print(f"\n✓ Saved to 'typo_dictionary.txt'")
    print(f"✓ Total corrections: {len(corrections)}")


def manual_typo_detection_workflow(df, interactive=True):
    """
    Complete manual typo detection workflow
    """
    print("="*80)
    print("MANUAL TYPO DETECTION WORKFLOW")
    print("="*80 + "\n")

    print("STEP 1: Extracting words...")
    all_words = extract_all_words(df)

    print("\nSTEP 2: Analyzing word patterns...")
    word_counts, frequent_words = analyze_words(all_words, min_frequency=5)

    print("\nSTEP 3: Finding suspicious patterns...")
    suspicious = find_suspicious_patterns(word_counts, min_frequency=5)

    print("\nSTEP 4: Finding similar word pairs...")
    pairs = find_similar_word_pairs(word_counts, min_frequency=10)

    print("\nSTEP 5: Displaying results...")
    display_top_words(word_counts, n=50)
    display_suspicious_words(suspicious)
    display_similar_pairs(pairs)

    print("\nSTEP 6: Saving results...")
    save_to_csv(word_counts, suspicious, pairs)

    corrections = {}
    if interactive:
        print("\n" + "="*80)
        review = input("\nStart interactive review? (y/n): ").lower()

        if review == 'y':
            print("\nReviewing suspicious words...")
            corrections1 = review_suspicious_words(suspicious)
            corrections.update(corrections1)

            if pairs:
                print("\n\nReviewing word pairs...")
                corrections2 = review_word_pairs(pairs)
                corrections.update(corrections2)

    if corrections:
        generate_typo_dict_code(corrections)

    print(f"\n{'='*80}")
    print("✓ WORKFLOW COMPLETE!")
    print(f"  Total unique words: {len(word_counts)}")
    print(f"  Suspicious words found: {len(suspicious)}")
    print(f"  Similar pairs found: {len(pairs)}")
    print(f"  Corrections created: {len(corrections)}")
    print(f"{'='*80}\n")

    return word_counts, suspicious, pairs, corrections



def quick_manual_detection(df):
    """
    Quick analysis without interaction - just generate CSVs to review
    """
    all_words = extract_all_words(df)
    word_counts, frequent_words = analyze_words(all_words, min_frequency=5)
    suspicious = find_suspicious_patterns(word_counts, min_frequency=5)
    pairs = find_similar_word_pairs(word_counts, min_frequency=10)

    display_suspicious_words(suspicious)
    display_similar_pairs(pairs)
    save_to_csv(word_counts, suspicious, pairs)

    print(f"\n{'='*80}")
    print("NEXT STEPS:")
    print(f"{'='*80}")
    print("1. Open 'all_words_frequency.csv' and look for typos")
    print("2. Review 'suspicious_words.csv' for likely typos")
    print("3. Check 'similar_word_pairs.csv' for typo variations")
    print("4. Add corrections to KNOWN_TYPOS dictionary")
    print(f"{'='*80}\n")

    return word_counts, suspicious, pairs

# %%
"""
# Option 1: Quick analysis (generates CSVs, no interaction)
word_counts, suspicious, pairs = quick_manual_detection(df)

# Option 2: Full workflow with interactive review
word_counts, suspicious, pairs, corrections = manual_typo_detection_workflow(df, interactive=True)

# Option 3: Just analyze and display (no files)
all_words = extract_all_words(df)
word_counts, frequent_words = analyze_words(all_words)
suspicious = find_suspicious_patterns(word_counts)
display_suspicious_words(suspicious)
"""

# %%
word_counts, suspicious, pairs, corrections = manual_typo_detection_workflow(df, interactive=True)
# Out:
# ================================================================================
# MANUAL TYPO DETECTION WORKFLOW
# ================================================================================
#
# STEP 1: Extracting words...
# Extracting words from: ['Title', 'Job Description', 'Job Requirements', 'Skills']
#
# Processing Title... ✓ (12019 rows)
# Processing Job Description... ✓ (12019 rows)
# Processing Job Requirements... ✓ (12019 rows)
# Processing Skills... ✓ (12019 rows)
#
# STEP 2: Analyzing word patterns...
#
# Analyzing 3637003 total words...
# Found 57956 unique words
#
# ================================================================================
# WORDS APPEARING 5+ TIMES: 17802
# ================================================================================
#
#
# STEP 3: Finding suspicious patterns...
#
# STEP 4: Finding similar word pairs...
# Finding similar word pairs...
#
# STEP 5: Displaying results...
#
# ================================================================================
# TOP 50 MOST FREQUENT WORDS
# ================================================================================
#
# Word                           Count
# --------------------------------------------------------------------------------
# and                            243692
# to                             103980
# the                            84876
# of                             70593
# in                             68716
# with                           54961
# a                              48091
# for                            33425
# or                             25808
# on                             18707
# is                             17222
# experience                     16622
# skills                         15915
# as                             15440
# s                              15370
# our                            13123
# are                            13006
# team                           12554
# work                           12206
# management                     12156
# all                            11958
# ensure                         11212
# you                            10507
# Management                     10308
# sales                          10117
# that                           10110
# years                          9725
# Sales                          9573
# Strong                         9215
# communication                  8767
# project                        8719
# business                       8584
# an                             8539
# Engineering                    8511
# will                           8463
# related                        8377
# requirements                   8328
# We                             8160
# be                             8050
# by                             7784
# customer                       7637
# technical                      7438
# including                      7373
# Experience                     7205
# quality                        6980
# teams                          6918
# standards                      6703
# performance                    6684
# Office                         6653
# degree                         6464
#
# ================================================================================
# SUSPICIOUS WORDS (Likely Typos)
# ================================================================================
#
# Word                           Count      Pattern
# --------------------------------------------------------------------------------
# experience                     16622      ence ending
# management                     12156      ment/gement
# Management                     10308      ment/gement
# Experience                     7205       ence ending
# performance                    6684       nce/nance
# compliance                     5607       nce/nance
# Manager                        4975       ger ending
# professiol                     3440       iol ending
# maintenance                    3128       nce/nance
# analysis                       2659       lysis
# Science                        2528       ence ending
# analytical                     2244       lytical
# Finance                        2240       nce/nance
# operatiol                      2209       iol ending
# intertiol                      1999       iol ending
# functiol                       1897       iol ending
# Ananalysis                     1894       lysis
# enhance                        1654       nce/nance
# position                       1412       ition ending
# engagement                     1266       ment/gement
# Intertiol                      1249       iol ending
# Maintenance                    1234       nce/nance
# insurance                      1157       nce/nance
# finance                        1115       nce/nance
# guidance                       957        nce/nance
# Compliance                     930        nce/nance
# adherence                      927        ence ending
# exceptiol                      906        iol ending
# Professiol                     883        iol ending
# excellence                     866        ence ending
# tiol                           811        iol ending
# accordance                     802        nce/nance
# Assurance                      801        nce/nance
# manager                        783        ger ending
# Ananalytical                   714        lytical
# assistance                     695        nce/nance
# regiol                         649        iol ending
# Additiol                       624        iol ending
# Performance                    596        nce/nance
# additiol                       557        iol ending
# assurance                      539        nce/nance
# presence                       525        ence ending
# Exceptiol                      480        iol ending
# Insurance                      471        nce/nance
# balance                        466        nce/nance
# Acquisition                    449        ition ending
# correspondence                 447        ence ending
# educatiol                      442        iol ending
# appearance                     442        nce/nance
# discrimition                   425        ition ending
# promotiol                      417        iol ending
# acquisition                    410        ition ending
# governce                       395        nce/nance
# science                        394        ence ending
# difference                     356        ence ending
# attendance                     341        nce/nance
# intelligence                   330        ence ending
# influence                      318        ence ending
# Position                       310        ition ending
# NPosition                      283        ition ending
# audience                       272        ence ending
# recognition                    260        ition ending
# freelance                      256        nce/nance
# Engagement                     254        ment/gement
# addition                       254        ition ending
# ledger                         247        ger ending
# chance                         238        nce/nance
# condition                      233        ition ending
# destition                      227        ition ending
# Regiol                         219        iol ending
# clearance                      210        nce/nance
# Educatiol                      196        iol ending
# Operatiol                      192        iol ending
# Excellence                     191        ence ending
# Functiol                       191        iol ending
# transition                     187        ition ending
# traditiol                      186        iol ending
# confidence                     180        ence ending
# eager                          176        ger ending
# allowance                      175        nce/nance
# ManagementPosition             172        ition ending
# resilience                     169        ence ending
# Intelligence                   163        ence ending
# reference                      160        ence ending
# variance                       143        nce/nance
# acceptance                     143        nce/nance
# occupatiol                     137        iol ending
# evidence                       136        ence ending
# issuance                       131        nce/nance
# Clearance                      130        nce/nance
# advance                        130        nce/nance
# since                          123        nce/nance
# multitiol                      123        iol ending
# ambition                       122        ition ending
# Governce                       116        nce/nance
# instructiol                    110        iol ending
# competition                    108        ition ending
# Ledger                         107        ger ending
# emotiol                        103        iol ending
# proposition                    100        ition ending
# organisatiol                   99         iol ending
# arrangement                    99         ment/gement
# EDITION                        97         ition ending
# Assistance                     96         nce/nance
# nutrition                      90         ition ending
# institutiol                    87         iol ending
# conference                     87         ence ending
# once                           85         nce/nance
# longer                         81         ger ending
# absence                        78         ence ending
# conformance                    76         nce/nance
# Freelance                      75         nce/nance
# Occupatiol                     75         iol ending
# Enhance                        72         nce/nance
# importance                     72         nce/nance
# diligence                      72         ence ending
# Balance                        70         nce/nance
# occasiol                       69         iol ending
# combition                      66         ition ending
# relatiol                       66         iol ending
# Since                          62         nce/nance
# preference                     61         ence ending
# passenger                      59         ger ending
# surveillance                   56         nce/nance
# SkillsOptiol                   56         iol ending
# relevance                      55         nce/nance
# competence                     55         ence ending
# imagition                      55         ition ending
# requisition                    54         ition ending
# rotatiol                       53         iol ending
# Rotatiol                       53         iol ending
# Emotiol                        53         iol ending
# LocationExperience             53         ence ending
# residence                      53         ence ending
# composition                    49         ition ending
# patience                       49         ence ending
# independence                   48         ence ending
# Instructiol                    43         iol ending
# Preference                     42         ence ending
# Allowance                      42         nce/nance
# elegance                       41         nce/nance
# Residence                      40         ence ending
# EXPERIENCE                     40         ence ending
# determition                    40         ition ending
# larger                         38         ger ending
# exhibition                     36         ition ending
# Recognition                    35         ition ending
# France                         35         nce/nance
# Bince                          34         nce/nance
# stronger                       34         ger ending
# vocatiol                       34         iol ending
# definition                     33         ition ending
# termition                      33         ition ending
# tradition                      33         ition ending
# conversatiol                   33         iol ending
# convenience                    30         ence ending
# essence                        30         ence ending
# Diligence                      29         ence ending
# tolerance                      29         nce/nance
# QualificationsExperience       29         ence ending
# Vocatiol                       28         iol ending
# examition                      28         ition ending
# recreatiol                     28         iol ending
# Exhibition                     27         ition ending
# Acceptance                     27         nce/nance
# sequence                       27         ence ending
# recurrence                     26         ence ending
# Influence                      26         ence ending
# optiol                         26         iol ending
# interventiol                   26         iol ending
# foundatiol                     26         iol ending
# Nutrition                      25         ition ending
# Definition                     25         ition ending
# defence                        25         ence ending
# Attendance                     25         nce/nance
# Transition                     24         ition ending
# Competence                     24         ence ending
# appliance                      24         nce/nance
# distance                       24         nce/nance
# Schrager                       24         ger ending
# Eager                          23         ger ending
# Requisition                    23         ition ending
# ordition                       23         ition ending
# Manger                         22         ger ending
# Alliance                       22         nce/nance
# Surveillance                   22         nce/nance
# conventiol                     22         iol ending
# Hilfiger                       22         ger ending
# Adherence                      22         ence ending
# Once                           22         nce/nance
# transformatiol                 21         iol ending
# judgement                      21         ment/gement
# IEEE                           21         double letters
# SkillsExperience               21         ence ending
# Resilience                     20         ence ending
# Confluence                     20         ence ending
# Confidence                     20         ence ending
# proteger                       20         ger ending
# Conference                     19         ence ending
# motivatiol                     19         iol ending
# profesiol                      19         iol ending
# Variance                       19         nce/nance
# Destition                      18         ition ending
# dimensiol                      18         iol ending
# Reference                      18         ence ending
# DescriptionPOSITION            18         ition ending
# bigger                         18         ger ending
# resistance                     17         nce/nance
# Optiol                         17         iol ending
# transactiol                    17         iol ending
# Chance                         17         nce/nance
# Correspondence                 17         ence ending
# noncompliance                  17         nce/nance
# conditiol                      16         iol ending
# Interventiol                   16         iol ending
# Guidance                       16         nce/nance
# POSITION                       16         ition ending
# DescriptionPosition            16         ition ending
# ambiance                       16         nce/nance
# MAGER                          15         ger ending
# Institutiol                    15         iol ending
# microfinance                   15         nce/nance
# inspiratiol                    15         iol ending
# Patience                       15         ence ending
# persistence                    15         ence ending
# Appliance                      15         nce/nance
# Condition                      14         ition ending
# cadence                        14         ence ending
# ApplicableSpecialismAssuranceManagement 14         ment/gement
# challenger                     14         ger ending
# Examition                      14         ition ending
# convince                       13         nce/nance
# origition                      13         ition ending
# inference                      13         ence ending
# skillsExperience               13         ence ending
# requiredExperience             13         ence ending
# fragrance                      13         nce/nance
# reputatiol                     12         iol ending
# Advance                        12         nce/nance
# tuition                        12         ition ending
# commence                       12         ence ending
# Appearance                     12         nce/nance
# Arrangement                    12         ment/gement
# alliance                       12         nce/nance
# announce                       12         nce/nance
# obsolescence                   11         ence ending
# grievance                      11         nce/nance
# computatiol                    11         iol ending
# apparence                      11         ence ending
# vigilance                      11         nce/nance
# divisiol                       11         iol ending
# Occasiol                       11         iol ending
# Conformance                    11         nce/nance
# occurrence                     11         ence ending
# Addition                       11         ition ending
# plusExperience                 11         ence ending
# brilliance                     11         nce/nance
# Difference                     11         ence ending
# manger                         10         ger ending
# Swagger                        10         ger ending
# Presence                       10         ence ending
# ExperienceExperience           10         ence ending
# AttributesExperience           10         ence ending
# Proposition                    10         ition ending
# BusinessSupervising            10         double letters
# contamition                    10         ition ending
# Composition                    10         ition ending
# Relatiol                       10         iol ending
# Issuance                       9          nce/nance
# dissemition                    9          ition ending
# merger                         9          ger ending
# attrition                      9          ition ending
# ambience                       9          ence ending
# hence                          9          ence ending
# dance                          9          nce/nance
# Divisiol                       8          iol ending
# Competition                    8          ition ending
# plusAdditiol                   8          iol ending
# excepciol                      8          iol ending
# licence                        8          ence ending
# experienceExperience           8          ence ending
# ServicesManagement             8          ment/gement
# OtherManagement                8          ment/gement
# Evidence                       8          ence ending
# TypeEmployeeManagement         8          ment/gement
# countryPerformance             8          nce/nance
# nutritiol                      8          iol ending
# hunger                         8          ger ending
# situatiol                      8          iol ending
# Boehringer                     8          ger ending
# requiredAdditiol               7          iol ending
# NumberPosition                 7          ition ending
# HILFIGER                       7          ger ending
# significance                   7          nce/nance
# Ambition                       7          ition ending
# systemsExperience              7          ence ending
# bounce                         7          nce/nance
# perseverance                   7          nce/nance
# coherence                      7          ence ending
# reconissance                   7          nce/nance
# Licence                        7          ence ending
# ProcessStage                   7          double letters
# Tolerance                      7          nce/nance
# desalition                     7          ition ending
# haveExperience                 7          ence ending
# multifunctiol                  7          iol ending
# Province                       6          nce/nance
# Messenger                      6          ger ending
# PERFORMANCE                    6          nce/nance
# ConsultingManagement           6          ment/gement
# OperationsManagement           6          ment/gement
# PROFESSIOL                     6          iol ending
# RequirementsExperience         6          ence ending
# AEDExperience                  6          ence ending
# timePosition                   6          ition ending
# vaccition                      6          ition ending
# teamsExperience                6          ence ending
# insuranceProfessiol            6          iol ending
# Bilfinger                      6          ger ending
# remittance                     6          nce/nance
# finger                         6          ger ending
# preferredExperience            6          ence ending
# danger                         6          ger ending
# Conversatiol                   6          iol ending
# Promotiol                      6          iol ending
# Behance                        6          nce/nance
# Sensatiol                      6          iol ending
# projectsExperience             6          ence ending
# Distance                       6          nce/nance
# Audition                       6          ition ending
# Organisatiol                   5          iol ending
# Disposition                    5          ition ending
# Multitiol                      5          iol ending
# preferredAdditiol              5          iol ending
# experince                      5          nce/nance
# fieldExperience                5          ence ending
# ForExperience                  5          ence ending
# HaveExperience                 5          ence ending
# QualificationsEducatiol        5          iol ending
# croissance                     5          nce/nance
# negligence                     5          ence ending
# WillLead                       5          double letters
# vocaciol                       5          iol ending
# sectiol                        5          iol ending
# skillsAdditiol                 5          iol ending
# trigger                        5          ger ending
# processesExperience            5          ence ending
# incondiciol                    5          iol ending
# entrance                       5          nce/nance
# disposition                    5          ition ending
# existence                      5          ence ending
# developmentExperience          5          ence ending
# nomition                       5          ition ending
# DhabiExperience                5          ence ending
# Independence                   5          ence ending
# Remittance                     5          nce/nance
#
# ================================================================================
# SIMILAR WORD PAIRS (Potential Typo Variations)
# ================================================================================
#
# Word 1                    Count    Word 2                    Count    Distance
# --------------------------------------------------------------------------------
# Site                      716      with                      54961    2
# City                      272      with                      54961    2
# Math                      51       with                      54961    2
# With                      825      with                      54961    0
# Fitch                     29       with                      54961    2
# city                      254      with                      54961    2
# High                      1558     with                      54961    2
# with                      54961    Wind                      12       2
# with                      54961    site                      3151     2
# with                      54961    within                    5023     2
# with                      54961    White                     31       2
# with                      54961    will                      8463     2
# with                      54961    high                      3823     2
# with                      54961    worth                     29       2
# with                      54961    both                      2319     2
# with                      54961    white                     67       2
# with                      54961    wish                      37       1
# with                      54961    which                     894      2
# with                      54961    path                      146      2
# with                      54961    wide                      517      2
# with                      54961    Ritz                      216      2
# with                      54961    sich                      16       2
# with                      54961    Wide                      39       2
# with                      54961    Write                     273      2
# with                      54961    Fifth                     27       2
# with                      54961    kits                      19       2
# with                      54961    sits                      14       2
# with                      54961    Will                      284      2
# with                      54961    auth                      10       2
# with                      54961    pitch                     57       2
# with                      54961    write                     180      2
# with                      54961    WITH                      26       0
# with                      54961    wire                      23       2
# with                      54961    math                      37       2
# with                      54961    Keith                     18       2
# with                      54961    fits                      29       2
# with                      54961    rich                      260      2
# with                      54961    Within                    31       2
# with                      54961    Citi                      21       2
# with                      54961    wins                      21       2
# with                      54961    wait                      62       2
# with                      54961    watch                     20       2
# with                      54961    Wash                      26       2
# with                      54961    WILL                      12       2
# with                      54961    Both                      16       2
# with                      54961    Path                      14       2
# with                      54961    Sita                      17       2
# with                      54961    switch                    15       2
# with                      54961    Pitch                     11       2
# with                      54961    wind                      14       2
#
# STEP 6: Saving results...
#
# ✓ Saved all words to 'all_words_frequency.csv'
# ✓ Saved suspicious words to 'suspicious_words.csv'
# ✓ Saved similar pairs to 'similar_word_pairs.csv'
#
# ================================================================================
#
# Start interactive review? (y/n): y
#
# Reviewing suspicious words...
#
# ================================================================================
# REVIEW SUSPICIOUS WORDS
# ================================================================================
#
# For each word:
#   y = It's a typo (then type correct spelling)
#   n = Not a typo (skip)
#   q = Quit review
#
#
# [1/356] 'experience' - ence ending (appears 16622 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [2/356] 'management' - ment/gement (appears 12156 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [3/356] 'Management' - ment/gement (appears 10308 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [4/356] 'Experience' - ence ending (appears 7205 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [5/356] 'performance' - nce/nance (appears 6684 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [6/356] 'compliance' - nce/nance (appears 5607 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [7/356] 'Manager' - ger ending (appears 4975 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [8/356] 'professiol' - iol ending (appears 3440 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'professiol': professional
#   ✓ Added: professiol → professional
#
# [9/356] 'maintenance' - nce/nance (appears 3128 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [10/356] 'analysis' - lysis (appears 2659 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [11/356] 'Science' - ence ending (appears 2528 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [12/356] 'analytical' - lytical (appears 2244 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [13/356] 'Finance' - nce/nance (appears 2240 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [14/356] 'operatiol' - iol ending (appears 2209 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'operatiol': operational
#   ✓ Added: operatiol → operational
#
# [15/356] 'intertiol' - iol ending (appears 1999 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'intertiol': international
#   ✓ Added: intertiol → international
#
# [16/356] 'functiol' - iol ending (appears 1897 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'functiol': functional
#   ✓ Added: functiol → functional
#
# [17/356] 'Ananalysis' - lysis (appears 1894 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'Ananalysis': Analysis
#   ✓ Added: Ananalysis → Analysis
#
# [18/356] 'enhance' - nce/nance (appears 1654 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [19/356] 'position' - ition ending (appears 1412 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [20/356] 'engagement' - ment/gement (appears 1266 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [21/356] 'Intertiol' - iol ending (appears 1249 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'Intertiol': International
#   ✓ Added: Intertiol → International
#
# [22/356] 'Maintenance' - nce/nance (appears 1234 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [23/356] 'insurance' - nce/nance (appears 1157 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [24/356] 'finance' - nce/nance (appears 1115 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [25/356] 'guidance' - nce/nance (appears 957 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [26/356] 'Compliance' - nce/nance (appears 930 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [27/356] 'adherence' - ence ending (appears 927 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [28/356] 'exceptiol' - iol ending (appears 906 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'exceptiol': exceptional
#   ✓ Added: exceptiol → exceptional
#
# [29/356] 'Professiol' - iol ending (appears 883 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'Professiol': Professional
#   ✓ Added: Professiol → Professional
#
# [30/356] 'excellence' - ence ending (appears 866 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [31/356] 'tiol' - iol ending (appears 811 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'tiol': National
#   ✓ Added: tiol → National
#
# [32/356] 'accordance' - nce/nance (appears 802 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [33/356] 'Assurance' - nce/nance (appears 801 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [34/356] 'manager' - ger ending (appears 783 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [35/356] 'Ananalytical' - lytical (appears 714 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'Ananalytical': Analytical
#   ✓ Added: Ananalytical → Analytical
#
# [36/356] 'assistance' - nce/nance (appears 695 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [37/356] 'regiol' - iol ending (appears 649 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'regiol': regional
#   ✓ Added: regiol → regional
#
# [38/356] 'Additiol' - iol ending (appears 624 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'Additiol': Additional
#   ✓ Added: Additiol → Additional
#
# [39/356] 'Performance' - nce/nance (appears 596 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [40/356] 'additiol' - iol ending (appears 557 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'additiol': additional
#   ✓ Added: additiol → additional
#
# [41/356] 'assurance' - nce/nance (appears 539 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [42/356] 'presence' - ence ending (appears 525 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [43/356] 'Exceptiol' - iol ending (appears 480 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'Exceptiol': Exceptional
#   ✓ Added: Exceptiol → Exceptional
#
# [44/356] 'Insurance' - nce/nance (appears 471 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [45/356] 'balance' - nce/nance (appears 466 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [46/356] 'Acquisition' - ition ending (appears 449 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [47/356] 'correspondence' - ence ending (appears 447 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [48/356] 'educatiol' - iol ending (appears 442 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'educatiol': educational
#   ✓ Added: educatiol → educational
#
# [49/356] 'appearance' - nce/nance (appears 442 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [50/356] 'discrimition' - ition ending (appears 425 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'discrimition': discrimination
#   ✓ Added: discrimition → discrimination
#
# [51/356] 'promotiol' - iol ending (appears 417 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'promotiol': promotional
#   ✓ Added: promotiol → promotional
#
# [52/356] 'acquisition' - ition ending (appears 410 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [53/356] 'governce' - nce/nance (appears 395 times)
# Is this a typo? (y/n/q): y
#   Correct spelling of 'governce': governance
#   ✓ Added: governce → governance
#
# [54/356] 'science' - ence ending (appears 394 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [55/356] 'difference' - ence ending (appears 356 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [56/356] 'attendance' - nce/nance (appears 341 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [57/356] 'intelligence' - ence ending (appears 330 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [58/356] 'influence' - ence ending (appears 318 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [59/356] 'Position' - ition ending (appears 310 times)
# Is this a typo? (y/n/q): n
#   ⊘ Skipped
#
# [60/356] 'NPosition' - ition ending (appears 283 times)
# Is this a typo? (y/n/q): q
#
#
# Reviewing word pairs...
#
# ================================================================================
# REVIEW SIMILAR WORD PAIRS
# ================================================================================
#
# For each pair, which is the typo?
#   1 = First word is typo
#   2 = Second word is typo
#   n = Neither is typo
#   q = Quit
#
#
# [1] 'Site' (716) vs 'with' (54961)
# Which is typo? (1/2/n/q): q
#
# ================================================================================
# GENERATED TYPO DICTIONARY CODE
# ================================================================================
#
# KNOWN_TYPOS = {
#     'Additiol': 'Additional',
#     'Ananalysis': 'Analysis',
#     'Ananalytical': 'Analytical',
#     'Exceptiol': 'Exceptional',
#     'Intertiol': 'International',
#     'Professiol': 'Professional',
#     'additiol': 'additional',
#     'discrimition': 'discrimination',
#     'educatiol': 'educational',
#     'exceptiol': 'exceptional',
#     'functiol': 'functional',
#     'governce': 'governance',
#     'intertiol': 'international',
#     'operatiol': 'operational',
#     'professiol': 'professional',
#     'promotiol': 'promotional',
#     'regiol': 'regional',
#     'tiol': 'National',
# }
#
# ✓ Saved to 'typo_dictionary.txt'
# ✓ Total corrections: 18
#
# ================================================================================
# ✓ WORKFLOW COMPLETE!
#   Total unique words: 57956
#   Suspicious words found: 356
#   Similar pairs found: 39244
#   Corrections created: 18
# ================================================================================

# %% [markdown]
# ### Converting to RAG format / Finetuning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12019 entries, 0 to 12354
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              12019 non-null  object
#  1   Company            12019 non-null  object
#  2   Job Type           12019 non-null  object
#  3   Work Setting       12019 non-null  object
#  4   Location           12019 non-null  object
#  5   Experience Needed  12019 non-null  object
#  6   Career Level       12019 non-null  object
#  7   Education Level    12019 non-null  object
#  8   Job Categories     12019 non-null  object
#  9   Skills             12019 non-null  object
#  10  Job Description    12019 non-null  object
#  11  Job Requirements   12019 non-null  object
#  12  Link               12019 non-null  object
#  13  Req_Extracted      12019 non-null  bool
# dtypes: bool(1), object(13)
# memory usage: 1.5+ MB

# %%
df.drop(columns=['Req_Extracted'], inplace=True)

# %%
df['Link'].duplicated().sum()
# Out:
# np.int64(388)

# %%
df = df.drop_duplicates(subset=["Link"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11631 entries, 0 to 12354
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              11631 non-null  object
#  1   Company            11631 non-null  object
#  2   Job Type           11631 non-null  object
#  3   Work Setting       11631 non-null  object
#  4   Location           11631 non-null  object
#  5   Experience Needed  11631 non-null  object
#  6   Career Level       11631 non-null  object
#  7   Education Level    11631 non-null  object
#  8   Job Categories     11631 non-null  object
#  9   Skills             11631 non-null  object
#  10  Job Description    11631 non-null  object
#  11  Job Requirements   11631 non-null  object
#  12  Link               11631 non-null  object
# dtypes: object(13)
# memory usage: 1.2+ MB

# %%
df.to_csv('wuzzuf_jobs_cleaned.csv', index=False)

# %%
# RAG Formatting:
import json
def format_for_rag(row):

    content_parts = []

    if pd.notna(row['Job Description']) and str(row['Job Description']).strip():
        content_parts.append(str(row['Job Description']))

    if pd.notna(row['Job Requirements']) and str(row['Job Requirements']).strip():
        content_parts.append("\n\nRequirements:\n" + str(row['Job Requirements']))

    full_content = "\n\n".join(content_parts).strip()

    return {
        'id': int(row.name),
        'title': str(row['Title']),
        'company': str(row['Company']),
        'skills': str(row['Skills']) if pd.notna(row['Skills']) else "",
        'career_level': str(row['Career Level']),
        'experience_needed': str(row['Experience Needed']),
        'location': str(row['Location']),
        'job_type': str(row['Job Type']),
        'work_setting': str(row['Work Setting']),
        'job_category': str(row['Job Categories']),
        'education_level': str(row['Education Level']),

        'content': full_content,

        'source_url': str(row['Link'])
    }

# %%
rag_data = df.apply(format_for_rag, axis=1).tolist()

with open('wuzzuf_for_rag.json', 'w', encoding='utf-8') as f:
    json.dump(rag_data, f, ensure_ascii=False, indent=2)

# %%
print(json.dumps(rag_data[0], indent=2, ensure_ascii=False))
# Out:
# {
#   "id": 0,
#   "title": "Administrative Mager",
#   "company": "OKX\n-",
#   "skills": "Administration, Office Magement, Microsoft Office, Secretary, Administration, Business Administration, Customer Service, Magement, English, Administrative Assistant",
#   "career_level": "Experienced (Non-Manager)",
#   "experience_needed": "Not Specified",
#   "location": "United Arab Emirates",
#   "job_type": "Freelance / Project",
#   "work_setting": "Not Specified",
#   "job_category": "Administration",
#   "education_level": "Not Specified",
#   "content": "- Who We AreAt OKX, we believe that the future will be reshaped by crypto, and ultimately contribute to every individual's freedom.OKX is a leading crypto exchange, and the developer of OKX Wallet, giving millions access to crypto trading and decentralized crypto applications (dApps). OKX is also a trusted brand by hundreds of large institutions seeking access to crypto markets. We are safe and reliable, backed by our Proof of Reserves.Across our multiple offices globally, we are united by our core principles: We Before Me, Do the Right Thing, and Get Things Done. These shared values drive our culture, shape our processes, and foster a friendly, rewarding, and diverse environment for every OK-er.OKX is part of OKG, a group that brings the value of Blockchain to users around the world, through our leading products OKX, OKX Wallet, OKLink and more.About The RoleWe are looking for a highly capable and driven Administrative Mager to lead our office operations in Dubai and provide regiol administrative support across the ME region. This role is ideal for an experienced professiol with good organizatiol acumen, strong logical thinking and alytical skills, excellent stakeholder magement skills, and the ability to drive initiatives in a fast-paced, tech-driven environment. Prior experience in fintech, crypto, or high-growth industries is a strong advantage.Key Responsibilities Office Management & Facilities OversightLead day-to-day office operations, ensuring a professiol, efficient, and well-maintained workplace. Coordite with building magement and vendors on repairs, cleaning, and facility upgrades. Mage space planning and future expansion requirements. Administer access card issuance, visitor controls, and front desk operations. Collaborate with global security teams on physical security policies and emergency procedures. Employee Engagement & Workplace CultureDesign and execute staff welfare initiatives, employee engagement programs, and regiol cultural events. Ensure inclusivity and cultural relevance in event planning and interl communications. Support onboarding experiences and promote a positive workplace environment. Vendor & Procurement ManagementOversee all local procurement processes, including vendor sourcing, contract negotiations, and cost control. Mage office inventory, assets, and non-laptop equipment, ensuring accurate record-keeping. Support audit readiness and ensure compliance with procurement and fincial policies. Budget Management & Data AnalysisMonitor budgets for office operations, staff events, and admin-related expenses. Provide regular reporting, cost alysis, and recommendations for efficiency improvements. Able to work with local/regiol fince, generate operation data to provide alysis reports for decision making and support charge-back models. Project Management & Office UpgradesLead or support fit-out projects, renovation efforts, and relocations. Work closely with vendors, designers, and interl stakeholders to ensure project timelines, quality, and branding alignment. Cross-Functiol & Regiol Business SupportAct as a liaison between Admin, HR, IT, and Finance teams to ensure smooth cross-functiol operations. Provide admin support to nearby regiol offices as required, ensuring alignment with company standards. Familiar with travel magement; experience with third-party travel booking is a plus. Qualifications5+ years of experience in office administration or facility magement, ideally in a regiol or multi-entity setup. Demonstrated success in vendor negotiation,event planning & execution, asset magement, and employee engagement. Strong fincial acumen for budgeting, tracking, and cost optimization, solid experience in reporting and data alysis. Fluent in English (written and spoken), another language is a plus. Proficiency in office tools and platforms, bonus if skilled in visual content (photography/video editing/newsletter creation). Familiarity with UAE labor laws, commercial leasing, and op ...
#   "source_url": "https://wuzzuf.net/jobs/p/g/dbwzazaspuhf-administrative-mager-okx-dubai-united-arab-emirates"
# }

# %%
# Finetuning Format:
def format_for_finetuning(row):

    output_parts = []

    if pd.notna(row['Job Description']) and str(row['Job Description']).strip():
        output_parts.append(str(row['Job Description']))

    if pd.notna(row['Job Requirements']) and str(row['Job Requirements']).strip():
        output_parts.append("\n\nRequirements:\n" + str(row['Job Requirements']))

    ideal_output = "\n\n".join(output_parts).strip()

    instruction = f"""Write a professional job posting for the following position:

Job Title: {row['Title']}
Career Level: {row['Career Level']}
Required Skills: {row['Skills']}
Experience Needed: {row['Experience Needed']}
Location: {row['Location']}
Job Type: {row['Job Type']}
Work Setting: {row['Work Setting']}

Generate a complete job description with responsibilities and requirements."""

    return {
        "instruction": instruction,
        "response": ideal_output,

        "metadata": {
            "job_category": str(row['Job Categories']),
            "career_level": str(row['Career Level']),
            "location": str(row['Location'])
        }
    }

# %%
finetuning_data = df.apply(format_for_finetuning, axis=1).tolist()

with open('wuzzuf_for_finetuning.jsonl', 'w', encoding='utf-8') as f:
    for item in finetuning_data:
        f.write(json.dumps(item, ensure_ascii=False) + '\n')
